# %%
import pandas as pd
#CARGA DE DATOS
archivo = "../data/interim/aprehendidos_detenidos/aprehendidos_detenidos_limpio.csv"

destino = "../data/processed/aprehendidos_detenidos/"

df_aprehendidos= pd.read_csv(archivo)
# Out:
# C:\Users\fernando\AppData\Local\Temp\ipykernel_4688\483568738.py:7: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aprehendidos= pd.read_csv(archivo)
#   codigo_iccs         tipo estado_civil estatus_migratorio edad    sexo  \
# 0   090111.03  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   31  HOMBRE
# 1   020721.02  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   21  HOMBRE
# 2   020111.11  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   27  HOMBRE
# 3   020112.05  APREHENDIDO    SOLTERO/A          NO_APLICA   24  HOMBRE
# 4   020721.02  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   35  HOMBRE
#
#       genero nacionalidad            autoidentificacion_etnica  \
# 0  MASCULINO  ECUATORIANO                            MESTIZO/A
# 1  MASCULINO  ECUATORIANO                            MESTIZO/A
# 2  MASCULINO  ECUATORIANO                         SE_DESCONOCE
# 3  MASCULINO  ECUATORIANO  AFROECUATORIANO/A  AFRODESCENDIENTE
# ...

# %%
df_aprehendidos.head()
# Out:
#   codigo_iccs         tipo estado_civil estatus_migratorio edad    sexo  \
# 0   090111.03  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   31  HOMBRE
# 1   020721.02  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   21  HOMBRE
# 2   020111.11  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   27  HOMBRE
# 3   020112.05  APREHENDIDO    SOLTERO/A          NO_APLICA   24  HOMBRE
# 4   020721.02  APREHENDIDO    SOLTERO/A       SE_DESCONOCE   35  HOMBRE
#
#       genero nacionalidad            autoidentificacion_etnica  \
# 0  MASCULINO  ECUATORIANO                            MESTIZO/A
# 1  MASCULINO  ECUATORIANO                            MESTIZO/A
# 2  MASCULINO  ECUATORIANO                         SE_DESCONOCE
# 3  MASCULINO  ECUATORIANO  AFROECUATORIANO/A  AFRODESCENDIENTE
# 4  MASCULINO  ECUATORIANO                            MESTIZO/A
#
#   nivel_de_instruccion  ... nombre_subcircuito codigo_provincia  \
# 0         SE_DESCONOCE  ...          7 LAGOS 2                9
# ...

# %%
df_aprehendidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61149 entries, 0 to 61148
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   codigo_iccs                61149 non-null  object
#  1   tipo                       61149 non-null  object
#  2   estado_civil               61149 non-null  object
#  3   estatus_migratorio         61149 non-null  object
#  4   edad                       61149 non-null  object
#  5   sexo                       61149 non-null  object
#  6   genero                     61149 non-null  object
#  7   nacionalidad               61149 non-null  object
#  8   autoidentificacion_etnica  61149 non-null  object
#  9   nivel_de_instruccion       61149 non-null  object
#  10  condicion                  61149 non-null  object
#  11  movilizacion               61149 non-null  object
#  12  tipo_arma                  61149 non-null  object
# ...
